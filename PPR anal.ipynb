# %% [markdown]
# # Paralelní programování

# %%
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats

import os
import pandas as pd
import numpy as np


# Set some Pandas options
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

# %% [markdown]
# ## Největší graf

# %%
graph_28_4 = pd.read_csv('graph_28_4.csv', index_col=0)
print graph_28_4
graph_28_4.plot(linewidth=2).set_ylabel('sekund')
# Out:
#          PT           IT
# P
# 1   1850.99  1850.990000
# 2   1042.07   925.495000
# 4    745.46   462.747500
# 6    517.64   308.498333
# 8    243.87   231.373750
# 10   198.01   185.099000
# 12   178.47   154.249167
# 14   181.11   132.213571
# 16   186.60   115.686875
# 18   179.99   102.832778
# 20   175.43    92.549500
# 22   183.41    84.135909
# 24   180.40    77.124583
# 26   186.50    71.191923
# 28   178.40    66.106786
# 30   181.20    61.699667
# 32   179.50    57.843438

# %% [markdown]
# ## Středně velký graf

# %%
graph_27_4 = pd.read_csv('graph_27_4.csv', index_col=0)
print graph_27_4
graph_27_4.plot(linewidth=2).set_ylabel('sekund')
# Out:
#             PT          IT
# P
# 1   829.491487  829.491487
# 2   413.432442  414.745744
# 4   216.908380  207.372872
# 6   147.520975  138.248581
# 8   117.843034  103.686436
# 10  104.753144   82.949149
# 12   89.241735   69.124291
# 14   89.538672   59.249392
# 16   88.816681   51.843218
# 18   90.610457   46.082860
# 20   94.267694   41.474574
# 22   84.408303   37.704159
# 24   91.656540   34.562145
# 26   86.987540   31.903519
# 28   92.789970   29.624696
# 30   81.489300   27.649716
# 32   90.457700   25.921609

# %% [markdown]
# ## Nejmenší graf

# %%
graph_26_4 = pd.read_csv('graph_26_4.csv', index_col=0)
print graph_26_4
graph_26_4.plot(linewidth=2).set_ylabel('sekund')
# Out:
#             PT          IT
# P
# 1   391.478929  391.478929
# 2   197.273237  195.739464
# 4   105.950843   97.869732
# 6    85.248890   65.246488
# 8    71.812161   48.934866
# 10   70.872420   39.147893
# 12   67.054808   32.623244
# 14   48.700313   27.962781
# 16   46.176686   24.467433
# 18   51.564850   21.748829
# 20   50.543112   19.573946
# 22   49.949811   17.794497
# 24   47.456500   16.311622
# 26   49.723600   15.056882
# 28   52.168400   13.981390
# 30   45.931600   13.049298
# 32   47.523600   12.233717
